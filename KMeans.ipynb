# %%
import pandas as pd # Mengimpor modul Pandas dan memberikan alias 'pd'. Pandas adalah library yang
#digunakan untuk manipulasi 
#dan analisis data, dan memberikan struktur data seperti DataFrame yang sangat berguna.
import numpy as np #Mengimpor modul NumPy dan memberikan alias 'np'. NumPy adalah library 
#yang menyediakan dukungan untuk array dan operasi matematika, sering digunakan dalam komputasi numerik
import matplotlib.pyplot as plt #Mengimpor modul pyplot dari Matplotlib dan memberikan alias 'plt'. 
#Matplotlib adalah library untuk membuat visualisasi grafik. Pyplot adalah modul di Matplotlib yang 
#menyediakan antarmuka serupa MATLAB untuk membuat visualisasi dengan mudah.
import seaborn as sns #Mengimpor modul Seaborn dan memberikan alias 'sns'. Seaborn adalah library 
#yang dibangun di atas Matplotlib, yang menyediakan antarmuka tingkat tinggi untuk membuat 
#visualisasi statistik yang menarik dan informatif.

# %%
df = pd.read_csv('WineQT.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df = df.drop(['Id'], axis=1)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 107.3 KB

# %%
#Cek Distribusi kolom Anual Income
plt.figure(figsize=(4,4))
sns.set(style='whitegrid')
sns.histplot(df['fixed acidity'], color='red', kde=True, stat='density',linewidth=0)
plt.title('Distribusi fixed acidity', fontsize=10)
plt.xlabel('Range fixed acidity')
plt.ylabel('Count')
plt.show()

# %%
#Cek Distribusi kolom Spending Score
plt.figure(figsize=(4,4))
sns.set(style='whitegrid')
sns.histplot(df['volatile acidity'], color='green', kde=True, stat='density',linewidth=0)
plt.title('Distribusi  volatile acidity', fontsize=10)
plt.xlabel('Range  volatile acidity')
plt.ylabel('Count')
plt.show()

# %%
#Cek Distribusi kolom Spending Score
plt.figure(figsize=(4,4))
sns.set(style='whitegrid')
sns.histplot(df['citric acid'], color='red', kde=True, stat='density',linewidth=0)
plt.title('Distribusi  citric acid', fontsize=10)
plt.xlabel('Range  citric acid')
plt.ylabel('Count')
plt.show()

# %%
#Cek Distribusi kolom Spending Score
plt.figure(figsize=(4,4))
sns.set(style='whitegrid')
sns.histplot(df['residual sugar'], color='green', kde=True, stat='density',linewidth=0)
plt.title('Distribusi  residual sugar', fontsize=10)
plt.xlabel('Range  residual sugar')
plt.ylabel('Count')
plt.show()

# %%
#Cek Distribusi kolom Spending Score
plt.figure(figsize=(4,4))
sns.set(style='whitegrid')
sns.histplot(df['free sulfur dioxide'], color='red', kde=True, stat='density',linewidth=0)
plt.title('Distribusi  free sulfur dioxide', fontsize=10)
plt.xlabel('Range  free sulfur dioxide')
plt.ylabel('Count')
plt.show()

# %%
#Cek Distribusi kolom Spending Score
plt.figure(figsize=(4,4))
sns.set(style='whitegrid')
sns.histplot(df['total sulfur dioxide'], color='red', kde=True, stat='density',linewidth=0)
plt.title('Distribusi  total sulfur dioxide', fontsize=10)
plt.xlabel('Range  total sulfur dioxide')
plt.ylabel('Count')
plt.show()

# %%
#Cek Distribusi kolom Spending Score
plt.figure(figsize=(4,4))
sns.set(style='whitegrid')
sns.histplot(df['density'], color='red', kde=True, stat='density',linewidth=0)
plt.title('Distribusi  density', fontsize=10)
plt.xlabel('Range  density')
plt.ylabel('Count')
plt.show()

# %%
#Cek Distribusi kolom Spending Score
plt.figure(figsize=(4,4))
sns.set(style='whitegrid')
sns.histplot(df['pH'], color='red', kde=True, stat='density',linewidth=0)
plt.title('Distribusi   pH', fontsize=10)
plt.xlabel('Range  pH')
plt.ylabel('Count')
plt.show()

# %%
#Cek Distribusi kolom Spending Score
plt.figure(figsize=(4,4))
sns.set(style='whitegrid')
sns.histplot(df['sulphates'], color='red', kde=True, stat='density',linewidth=0)
plt.title('Distribusi   sulphates', fontsize=10)
plt.xlabel('Range  sulphates')
plt.ylabel('Count')
plt.show()

# %%
#Cek Distribusi kolom Spending Score
plt.figure(figsize=(4,4))
sns.set(style='whitegrid')
sns.histplot(df['alcohol'], color='red', kde=True, stat='density',linewidth=0)
plt.title('Distribusi   alcohol', fontsize=10)
plt.xlabel('Range  alcohol')
plt.ylabel('Count')
plt.show()

# %%
#Cek Distribusi kolom Spending Score
plt.figure(figsize=(4,4))
sns.set(style='whitegrid')
sns.histplot(df['quality'], color='red', kde=True, stat='density',linewidth=0)
plt.title('Distribusi   quality', fontsize=10)
plt.xlabel('Range quality')
plt.ylabel('Count')
plt.show()

# %%
#Menentukan Cluster  Terbaik (Elbow Method)
#Hitung Within Cluster sum of Squared error (WCSS) untuk tiap kluster yang berbeda
from sklearn.cluster import KMeans
wcss=[]
for i in range (1,11):
    kmModel=KMeans(n_clusters=i,n_init=10)
    kmModel.fit(df)
    wcss.append(kmModel.inertia_)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,11), wcss)
plt.plot(range(1,11), wcss, linewidth=2, color='red', marker='8')
plt.xlabel('Jumlah Cluster')
plt.xticks(np.arange(1,11,1))
plt.ylabel('WCSS')
plt.show()

# %%
# Model Dengan 5 Cluster
kmModelfix=KMeans(n_clusters=2,n_init=10)
kmModelfix.fit(df)

#Memprediksi Label
hasil_prediksi = kmModelfix.predict(df)
print(hasil_prediksi)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# [0 1 0 ... 0 0 0]

# %%
df['Label']=hasil_prediksi
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Label
# 0      9.4        5      0
# 1      9.8        5      1
# ...

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
from sklearn.metrics import silhouette_score

# df adalah data yang digunakan untuk klastering
# hasil_prediksi adalah hasil klaster yang didapat dari model klastering
silhouette_avg = silhouette_score(df, hasil_prediksi)

print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Silhouette Score: 0.5985390553097255

# %%
import pandas as pd

# Buat dataframe baru dengan fitur yang sesuai masukin satu" semuanya
data_baru = {'fixed acidity': 4,
             'volatile acidity': 0.6,
             'citric acid':1.9,
             
             # ... tambahkan fitur lainnya sesuai dengan model Anda
            }

df_data_baru = pd.DataFrame(data_baru)

# Prediksi label klaster untuk data baru
hasil_prediksi_data_baru = kmModelfix.predict(df_data_baru)

# Tampilkan hasil prediksi
print(f'Prediksi label klaster untuk data baru: {hasil_prediksi_data_baru}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 5
#       1 import pandas as pd
#       3 # Buat dataframe baru dengan fitur yang sesuai
#       4 data_baru = {'fixed acidity': 4,
# ----> 5              'Fitur2': [nilai2],
#       6              # ... tambahkan fitur lainnya sesuai dengan model Anda
#       7             }
#       9 df_data_baru = pd.DataFrame(data_baru)
#      11 # Prediksi label klaster untuk data baru
#
# NameError: name 'nilai2' is not defined

# %%
# Menampilkan persebaran data pada setiap kluster
cluster_distribution = df['Label'].value_counts()

# Menampilkan hasil
print(cluster_distribution)
# Out:
# 0    847
# 1    296
# Name: Label, dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x='volatile acidity', y = 'total sulfur dioxide', hue = 'Label',
               palette=['green','brown','orange','dodgerblue','red'], legend='full',
               data = df, s = 60)
plt.title('Persebaran Data')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_28888\3025993353.py:2: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.scatterplot(x='volatile acidity', y = 'total sulfur dioxide', hue = 'Label',
